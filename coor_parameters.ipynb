# %%
import matplotlib as mpl
import cv_param_checker as cvpc
reload(cvpc)
read_xyz = cvpc.read_xyz
COOR_RF = cvpc.COOR_RF
DIFCOOR = cvpc.DIFCOOR

dirpath = '/home/tzelleke/projects/madh/scaled/cpmd/analysis/qmmm/coordination_number/raw_data/'
reactant = ['frame_049.CM_HM123_OD12.xyz',
             'frame_073.CM_HM123_OD12.xyz',
             'frame_112.CM_HM123_OD12.xyz',
             'frame_137.CM_HM123_OD12.xyz',
             'frame_147.CM_HM123_OD12.xyz',
             'frame_201.CM_HM123_OD12.xyz',
             'frame_217.CM_HM123_OD12.xyz',
             'frame_242.CM_HM123_OD12.xyz']
proton_OD1 = ['proton_on_OD1.CM_HM123_OD12.xyz']
proton_OD2 = ['proton_on_OD2.CM_HM123_OD12.xyz']
ts_OD1 = ['strong_restraint_HM1-OD1_ts.CM_HM123_OD12.xyz',
          'weak_restraint_HM1-OD1_ts.CM_HM123_OD12.xyz']
ts_OD2 = ['strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz',
          'weak_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz']

files = (reactant[0], proton_OD1[0], proton_OD2[0], ts_OD1[0], ts_OD2[0])

data, names = [], []
for f in files:
    fname = dirpath + f
    d, n = read_xyz(fname)
    data.append(d)
    names.append(n)

# %%
from numpy import arange

d0s = arange(0.1, 3.0, 0.1).tolist()

print 'OD1 started'
result_OD1 = res = []
for i in range(len(files)):
    coor_rf = COOR_RF(data[i], [4], [1,2,3])
    res.append(coor_rf(d0s))
    print '  ', f
print 'OD1 finished'
# Out:
# OD1 started
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
# OD1 finished

# %%
print 'OD2 started'
result_OD2 = res = []
for i in range(len(files)):
    coor_rf = COOR_RF(data[i], [5], [1,2,3])
    res.append(coor_rf(d0s))
    print '  ', f
print 'OD2 finished'
# Out:
# OD2 started
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
# OD2 finished

# %%
print 'OD1 - OD2 started'
result_OD1_OD2 = res = []
for i in range(len(files)):
    difcoor = DIFCOOR(data[i], [4], [5], [1,2,3])
    res.append(difcoor(d0s))
    print '  ', f
print 'OD1 - OD2 finished'
# Out:
# OD1 - OD2 started
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#    strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
#  strong_restraint_HM2-OD2_ts.CM_HM123_OD12.xyz
# OD1 - OD2 finished

# %%
def nicify(ax):
    #set the style of the major and minor grid lines, filled blocks
    ax.grid(True, 'major', color='w', linestyle='-', linewidth=1.4)
    ax.grid(True, 'minor', color='0.92', linestyle='-', linewidth=0.7)
    ax.patch.set_facecolor('0.85')
    ax.set_axisbelow(True)
    
    #set minor tick spacing to 1/2 of the major ticks
    ax.xaxis.set_minor_locator(MultipleLocator((xticks()[0][1]- xticks()[0][0]) / 2.0 ))
    ax.yaxis.set_minor_locator(MultipleLocator((yticks()[0][1]- yticks()[0][0]) / 2.0 ))
    
    #remove axis border
    for child in ax.get_children():
        if isinstance(child, matplotlib.spines.Spine):
            child.set_alpha(0)
       
    #restyle the tick lines
    for line in ax.get_xticklines() + ax.get_yticklines():
        line.set_markersize(5)
        line.set_color("gray")
        line.set_markeredgewidth(1.4)
    
    #remove the minor tick lines    
    for line in ax.xaxis.get_ticklines(minor=True) + ax.yaxis.get_ticklines(minor=True):
        line.set_markersize(0)
    
    #only show bottom left ticks, pointing out of axis
    rcParams['xtick.direction'] = 'out'
    rcParams['ytick.direction'] = 'out'
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
    if ax.legend_ <> None:
        lg = ax.legend_
        lg.legendPatch.set_facecolor('0.97')

# %%
options = [{'fmt': '-', 'color': 'Black', 'marker': 'o', 'mfc': 'DarkOrange'},
           {'fmt': '-', 'color': 'MidnightBlue', 'marker': 's', 'mfc': 'Crimson'},
           {'fmt': '-', 'color': 'DarkGreen', 'marker': 's', 'mfc': 'GreenYellow'},
           {'fmt': '--', 'color': 'MidnightBlue', 'marker': '+'},
           {'fmt': '--', 'color': 'DarkGreen', 'marker': '+'}]

# %%
def cv_plot(res):
    figsize(12.8, 6.6)
    errorbar(res[3][:,0], res[3][:,1], res[3][:,2]/2, label='ts OD1', **options[3])
    errorbar(res[4][:,0], res[4][:,1], res[4][:,2]/2, label='ts OD2', **options[4])
    errorbar(res[0][:,0], res[0][:,1], res[0][:,2]/2, label='reactant', **options[0])
    errorbar(res[1][:,0], res[1][:,1], res[1][:,2]/2, label='product OD1', **options[1])
    errorbar(res[2][:,0], res[2][:,1], res[2][:,2]/2, label='product OD2', **options[2])

# %%
cv_plot(result_OD1)

title('Coordination number OD1 w.r.t. HM[1,2,3]', fontsize=24)
ylim(-0.1, 2)
legend(loc=2)
nicify(gca())
savefig('coor_rf_OD1.png');

# %%
cv_plot(result_OD2)

title('Coordination number OD2 w.r.t. HM[1,2,3]', fontsize=24)
ylim(-0.1, 2)
legend(loc=2)
nicify(gca())
savefig('coor_rf_OD2.png');

# %%
cv_plot(result_OD1_OD2)

title('Difference coord. numbers [OD1,OD2] w.r.t. HM[1,2,3]', fontsize=24)
ylim(-1, 1)
legend(loc=2)
nicify(gca())
savefig('difcoor_OD1_OD2.png');
